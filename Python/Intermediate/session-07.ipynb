# %% [markdown]
# # Session 7 🐍

# %% [markdown]
# ☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️

# %% [markdown]
# ***

# %% [markdown]
# # 56. Seaborn
# Seaborn is a powerful Python data visualization library built on top of Matplotlib. It provides a high-level interface for creating attractive and informative statistical graphics.

# %% [markdown]
# ***

# %% [markdown]
# # 57. Introduction to Seaborn
# - Built on Matplotlib but with simpler syntax
# - Beautiful default styles and color palettes
# - Excellent support for pandas DataFrames
# - Specialized functions for statistical visualizations
# - Easy to create complex visualizations with minimal code

# %% [markdown]
# ***

# %% [markdown]
# # 58. Main Plot Types

# %% [markdown]
# ***

# %% [markdown]
# ## 58-1. Relational Plots
# - scatterplot(): Relationship between two numerical variables
# - lineplot(): Relationship with continuity (typically over time)

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ***

# %% [markdown]
# ## 58-2. Distribution Plots
# - histplot(): Histogram of a single variable
# - kdeplot(): Kernel Density Estimate plot
# - ecdfplot(): Empirical Cumulative Distribution Function
# - rugplot(): Marginal ticks for a distribution

# %%
sns.histplot(data=tips, x="total_bill", kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ***

# %% [markdown]
# ## 58-3. Categorical Plots
# - barplot(): Point estimates and confidence intervals
# - countplot(): Count of observations in each category
# - boxplot(): Five-number summary of distribution
# - violinplot(): Combination of boxplot and KDE
# - stripplot(): Scatterplot for categorical data
# - swarmplot(): Non-overlapping points for categorical data

# %%
sns.boxplot(data=tips, x="day", y="total_bill", hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ***

# %% [markdown]
# ## 58-4. Regression Plots
# - regplot(): Linear regression model fit
# - lmplot(): Combines regplot() with FacetGrid

# %%
sns.regplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ***

# %% [markdown]
# ## 58-5. Matrix Plots
# - heatmap(): Rectangular data as color-encoded matrix
# - clustermap(): Hierarchically-clustered heatmap

# %%
flights = sns.load_dataset("flights")
flights_matrix = flights.pivot("month", "year", "passengers")
sns.heatmap(flights_matrix, annot=True, fmt="d")
# Out:
# C:\Users\t430\AppData\Local\Temp\ipykernel_23520\2074057271.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_matrix = flights.pivot("month", "year", "passengers")
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ***

# %% [markdown]
# ## 58-6. Multi-plot Grids
# - FacetGrid: Subplot grid for plotting conditional relationships
# - PairGrid: Grid of subplots for pairwise relationships
# - jointplot(): Joint distribution plot with marginal distributions

# %%
g = sns.FacetGrid(tips, col="time", row="smoker")
g.map(sns.scatterplot, "total_bill", "tip")

# %% [markdown]
# ***

# %% [markdown]
# # 59. Customization

# %% [markdown]
# ***

# %% [markdown]
# ## 59-1. Themes and Styles
# Available styles: "darkgrid", "whitegrid", "dark", "white", "ticks"

# %%
sns.set_theme(style="whitegrid", palette="deep", font_scale=1.2)

# %% [markdown]
# ***

# %% [markdown]
# ## 59-2. Color Palettes

# %%
sns.color_palette("husl", 8)  # Qualitative
sns.color_palette("Blues")    # Sequential
sns.color_palette("coolwarm") # Diverging
# Out:
# [(0.4044212904941176, 0.5346434904470588, 0.9320019126352941),
#  (0.603162067917647, 0.7315274773529412, 0.9995652785372549),
#  (0.7867207013568628, 0.8448072103686275, 0.9398103849490196),
#  (0.9306685963333333, 0.818876999654902, 0.7591463906980392),
#  (0.9673165156666667, 0.6574708288078431, 0.5381601507294118),
#  (0.8846434386941177, 0.41001709788235297, 0.32250654924705885)]

# %% [markdown]
# ***

# %% [markdown]
# ## 59-3. Plot Aesthetics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(data=tips, x="day", y="total_bill", 
            hue="sex", palette="pastel",
            edgecolor=".6", linewidth=2.5)
plt.title("Daily Total Bill by Gender")
plt.xlabel("Day of Week")
plt.ylabel("Total Bill ($)")
plt.legend(title="Gender")

# %% [markdown]
# ***

# %% [markdown]
# # 60. Advanced Features

# %% [markdown]
# ***

# %% [markdown]
# ## 60-1. Statistical Estimation
# Seaborn automatically calculates and displays:
# - Confidence intervals
# - Regression lines
# - Aggregation statistics

# %% [markdown]
# ***

# %% [markdown]
# ## 60-2. Working with Pandas
# Seaborn integrates seamlessly with pandas DataFrames:

# %%
sns.boxplot(data=df, x="category", y="value")

# %% [markdown]
# ***

# %% [markdown]
# ## 60-3. Pair Plots

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris, hue="species")

# %% [markdown]
# ***

# %% [markdown]
# ## 60-4. Joint Plots

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", kind="hex")

# %% [markdown]
# ***

# %% [markdown]
# ## 60-5. Categorical Plot Combination

# %%
sns.catplot(data=tips, x="day", y="total_bill", 
            hue="sex", kind="violin", split=True)

# %% [markdown]
# ***

# %% [markdown]
# # 61. Saving Plots

# %%
fig = sns.scatterplot(...)
fig.figure.savefig("plot.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ***

# %% [markdown]
# # 62. When to Use Seaborn vs. Matplotlib
# Use Seaborn when:
# - You need quick, beautiful statistical visualizations
# - Working with pandas DataFrames
# - Need complex visualizations with minimal code
# - Want consistent styling across plots
#
# Use Matplotlib when:
# - You need maximum customization
# - Creating non-standard plot types
# - Need fine-grained control over plot elements

# %% [markdown]
# ***

# %% [markdown]
# # 63. Example

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Loading dataset
diamonds = sns.load_dataset("diamonds")

# Setting style
sns.set_theme(style="whitegrid", palette="muted")

# Creating plot
g = sns.displot(
    data=diamonds,
    x="price", col="cut", row="color",
    kind="kde", height=3, facet_kws=dict(margin_titles=True),
)

# Customizing
g.set_axis_labels("Price (USD)", "Density")
g.set_titles(col_template="{col_name} cut", row_template="{row_name} color")
plt.suptitle("Diamond Price Distribution by Cut and Color", y=1.02)

# Saving
plt.savefig("diamonds.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # Some Excercises

# %% [markdown]
# **1.**  Use the **tips** dataset to create:
# - A scatterplot of total_bill vs tip, colored by time.
# - A lineplot of total_bill vs size, aggregating with mean and a 95% confidence interval.

# %% [markdown]
# ___

# %% [markdown]
# **2.** Using the **penguins** dataset:
# - Plot a histogram of flipper_length_mm with KDE.
# - Overlay a rugplot on the same figure.
# - Create an ECDF plot for body_mass_g.

# %% [markdown]
# ---

# %% [markdown]
# **3.**  Using the **titanic** dataset:
# - Create a countplot of passengers by class.
# - Compare age distribution across class using a violinplot.
# - Show fare distribution per class using a swarmplot (avoid overplotting).

# %% [markdown]
# ---

# %% [markdown]
# **4.**  Using the **diamonds** dataset (sample 500 rows for speed):
# - Fit a linear regression (regplot) between carat and price.
# - Create a heatmap of the correlation matrix (numerical columns only).

# %% [markdown]
# ***

# %% [markdown]
# **5.** Using the **iris** dataset:
# - Create a FacetGrid of sepal_length vs sepal_width, split by species.
# - Use pairplot to compare all numerical variables, colored by species.

# %% [markdown]
# ***

# %% [markdown]
# **6.** Using the **mpg** dataset:
# - Set a dark theme with "deep" palette.
# - Plot horsepower vs mpg in a scatterplot, with:
#     - Custom markers ("s" for square).
#     - Adjusted opacity (alpha=0.7).
#     - A title and axis labels.

# %% [markdown]
# ***

# %% [markdown]
# **7.** Using the **penguins** dataset:
# - Create a jointplot of bill_length_mm vs bill_depth_mm with kind="hex".
# - Make a clustermap of the correlation matrix (numerical columns).

# %% [markdown]
# ***

# %% [markdown]
# **8.** Recreate any of the above plots with custom styling.
# - Save it as a 300 DPI PNG with bbox_inches="tight".
# - Compare performance: Try the same plot in Matplotlib (if applicable).

# %% [markdown]
# ***

# %% [markdown]
# #                                                        🌞 https://github.com/AI-Planet 🌞
