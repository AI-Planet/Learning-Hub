# %% [markdown]
# # Session 6 🐍

# %% [markdown]
# ☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️☀️

# %% [markdown]
# ***

# %% [markdown]
# # 47. Matplotlib
# Matplotlib is the most widely used Python library for data visualization and plotting. It provides an object-oriented API for embedding plots into applications and creating publication-quality figures in a variety of formats.

# %% [markdown]
# ***

# %% [markdown]
# # 48. Basic Plotting

# %% [markdown]
# ***

# %% [markdown]
# ## 48-1. Simple Line Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 48-2. Scatter Plot

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5)
plt.colorbar()  # Adds color bar
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 48-3. Bar Chart

# %%
labels = ['A', 'B', 'C', 'D']
values = [10, 30, 20, 25]

plt.bar(labels, values)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # 49. Figure and Axes Objects
# The object-oriented approach is preferred for more control:

# %%
fig, ax = plt.subplots()  
ax.plot(x, y, label='sin(x)')  
ax.set_title("Sine Wave")  
ax.set_xlabel("x")  
ax.set_ylabel("sin(x)")  
ax.legend()  
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 49-1. Figure Customization

# %%
fig = plt.figure(figsize=(8, 6), dpi=100, facecolor='lightgray')
ax = fig.add_subplot(111)  # 1 row, 1 column, 1st subplot
ax.plot(x, y)
fig.suptitle("Main Title", fontsize=16)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # 50. Common Plot Types

# %% [markdown]
# ***

# %% [markdown]
# ## 50-1. Histogram

# %%
data = np.random.randn(1000)
plt.hist(data, bins=30, density=True, alpha=0.7, color='blue')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 50-2. Pie Chart

# %%
sizes = [15, 30, 45, 10]
labels = ['A', 'B', 'C', 'D']
explode = (0, 0.1, 0, 0)  

plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.axis('equal')  
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 50-3. Box Plot

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
plt.boxplot(data, vert=True, patch_artist=True)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 50-4. Heatmap

# %%
data = np.random.rand(10, 12)
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # 51. Customizing Plots

# %% [markdown]
# ***

# %% [markdown]
# ## 51-1. Line Styles and Markers

# %%
x = np.linspace(0, 10, 20)
plt.plot(x, x, '-', label='solid')  # solid
plt.plot(x, x+1, '--', label='dashed')  # dashed
plt.plot(x, x+2, ':', label='dotted')  # dotted
plt.plot(x, x+3, '-.', label='dashdot')  # dashdot
plt.plot(x, x+4, 'o', label='circles')  # circles
plt.legend()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 51-2. Colors
# Matplotlib supports:

# %%
Named colors ('red', 'blue')

Hex strings ('#FF0000')

RGB/RGBA tuples ((1,0,0,1))

Grayscale intensities ('0.7')
# Out:
# array([1., 1., 1., 1., 1.])

# %% [markdown]
# ***

# %% [markdown]
# ## 51-3. Text and Annotations

# %%
ax.text(5, 0.5, "Important Point", fontsize=12)
ax.annotate("Maximum", xy=(np.pi/2, 1), xytext=(np.pi/2, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(1.5707963267948966, 1.5, 'Maximum')

# %% [markdown]
# ***

# %% [markdown]
# ## 51-4. Styles
# Matplotlib comes with several built-in styles:

# %%
plt.style.use('ggplot')

# %% [markdown]
# ***

# %% [markdown]
# # 52. Subplots and Multiple Axes

# %% [markdown]
# ***

# %% [markdown]
# ## 52-1. Basic Subplots

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x))
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 52-2. GridSpec for Complex Layouts

# %%
fig = plt.figure(figsize=(10, 8))
gs = fig.add_gridspec(2, 2)

ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[1, :])

ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x))
ax3.plot(x, np.tan(x))
plt.tight_layout()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 52-3. Insets

# %%
fig, ax = plt.subplots()
ax.plot(x, np.sin(x))

# Create inset
ax_inset = ax.inset_axes([0.6, 0.6, 0.3, 0.3])
ax_inset.plot(x, np.cos(x))
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # 53. 3D Plotting

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # 54. Animations

# %%
from matplotlib.animation import FuncAnimation

fig, ax = plt.subplots()
x = np.linspace(0, 2*np.pi, 100)
line, = ax.plot(x, np.sin(x))

def update(frame):
    line.set_ydata(np.sin(x + frame/10))
    return line,

ani = FuncAnimation(fig, update, frames=100, interval=50)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # 55. Working with Real Data

# %% [markdown]
# ***

# %% [markdown]
# ## 55-1. With Pandas

# %%
import pandas as pd

df = pd.read_csv('data.csv')
df.plot(x='date', y='value', kind='line')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 55-2. Time Series

# %%
dates = pd.date_range('20230101', periods=100)
df = pd.DataFrame(np.random.randn(100, 3), index=dates, columns=list('ABC'))
df.plot()
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 55-3. Categorical Data

# %%
df = pd.DataFrame({
    'Category': ['A', 'B', 'C', 'D'],
    'Values': [10, 20, 15, 30]
})
df.plot.bar(x='Category', y='Values')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ***

# %% [markdown]
# # Some Excercises

# %% [markdown]
# **1.**  Plot a sine wave and a cosine wave on the same figure.
# - Use np.linspace(0, 2*np.pi, 100) for x-values.
# - Customize the plot with:
# - Title ("Sine and Cosine Waves")
# - X-label ("Angle (radians)")
# - Y-label ("Value")
# - Legend
# - Grid

# %% [markdown]
# ___

# %% [markdown]
# **2.** Create a bar chart showing the average scores of 5 students with error bars.
#
# Data:
# - Students = ["Alice", "Bob", "Charlie", "Dave", "Eve"]
# - Scores = [85, 72, 90, 65, 88]
# - Errors = [5, 3, 7, 4, 6]
# - Add labels, title ("Student Scores"), and customize bar colors.

# %% [markdown]
# ---

# %% [markdown]
# **3.**  Generate a scatter plot where:
# - x = np.random.rand(100)
# - y = np.random.rand(100)
# - colors = np.random.rand(100)
# - sizes = 500 * np.random.rand(100)
# - Add a colorbar and title ("Random Scatter Plot").

# %% [markdown]
# ---

# %% [markdown]
# **4.**  Plot a histogram of normally distributed data (np.random.randn(1000)) with:
# - 30 bins
# - Overlay a kernel density estimate (use sns.kdeplot if needed)
# - Title ("Normal Distribution")
# - Legend

# %% [markdown]
# ***

# %% [markdown]
# **5.** Create a 2x2 grid of subplots showing:
# - A line plot (y = x²)
# - A scatter plot (random points)
# - A bar chart (custom data)
# - A histogram (random normal data)
# - Add titles for each subplot.

# %% [markdown]
# ***

# %% [markdown]
# **6.** Create a pie chart for market share data:
# - Labels: ["Apple", "Samsung", "Huawei", "Others"]
# - Sizes: [45, 30, 15, 10]
# - Explode the "Apple" slice by 0.1
# - Add percentage labels
# - Shadow effect

# %% [markdown]
# ***

# %% [markdown]
# **7.** Generate a fake time series:
# - dates = pd.date_range("2023-01-01", periods=100)
# - prices = 100 + np.cumsum(np.random.randn(100))
# - df = pd.DataFrame({"Price": prices}, index=dates)
# - Plot with:
#     - Title ("Stock Price Over Time")
#     - X-label ("Date")
#     - Y-label ("Price ($)")
#     - Grid

# %% [markdown]
# ***

# %% [markdown]
# **8.** Plot a 3D surface of z = sin(sqrt(x² + y²)).
# - Use np.linspace(-5, 5, 100) for x and y.
# - Add labels ("X", "Y", "Z").
# - Use a colormap (cmap='viridis').

# %% [markdown]
# ***

# %% [markdown]
# #                                                        🌞 https://github.com/AI-Planet 🌞
